# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
os.chdir('/Users/siu/Library/CloudStorage/OneDrive-STANDIGM/MP402_PIP4K2A/1st_library_screening_res/star_res')
os.listdir()
# Out:
# ['MP00402_stadium_chart.xlsx',
#  '2A_ste_docked_props.sdf',
#  '2A_ste_docked.sdf',
#  '2B_ste_docked_props.csv',
#  '2B_ste_docked.sdf',
#  'MP402_STADIUM_25cpds_2B.csv',
#  'MP402_STADIUM_25cpds_2A.csv',
#  '2A_ste_docked_props.csv',
#  '2B_ste_docked_props.sdf',
#  '2A_ste_docked_props.maegz',
#  '2B_ste_docked_props.maegz']

# %%
df = pd.read_csv('2B_ste_docked_props.csv')

# %%
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.color'] = 'r'
plt.rcParams['axes.grid'] = False

fig,ax = plt.subplots()
fig.autofmt_xdate(rotation=45)
ax.set_title('Gold Score of STADIUMs in PIP4K2A')

plt.bar(df['NAME'], df['Gold.Chemscore.Fitness'])
plt.show()

# %%
fig,ax = plt.subplots()
fig.autofmt_xdate(rotation=45)
ax.set_title('STAR Score of STADIUMs in PIP4K2A')

plt.bar(df['NAME'], df['star_score'])
plt.show()

# %%
plt.rcParams["figure.figsize"] = (10,10)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.color'] = 'r'
plt.rcParams['axes.grid'] = False

plt.scatter(df['Gold.Chemscore.Fitness'], df['star_score'])
plt.show()
